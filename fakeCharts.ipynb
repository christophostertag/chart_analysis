# %%
from myFunctions import *
# Out:
# Using TensorFlow backend.

# %%
#try fake plotting
originalPrices = [1 for i in range(100)]
fakePrices = getFakePrices(originalPrices, 10, 10)

#for fakePrice in fakePrices:
for fakePrice in fakePrices:
    plt.plot(fakePrice)
plt.ylim([0,2])
plt.xlim(0,99)
plt.show()

# %%
#try getting extra entries
testPrices = [0.8,0.8,0.8,0.8,1.2,0.8,1.2,1.4,1.2,1.4,1.2,0.8,1.2,0.8,0.8,0.8]
plt.plot(testPrices)
plt.show()
extraEntries = getExtraEntries(testPrices,10)
plt.plot(extraEntries)
plt.show()

# %%
#pre settings for synthetic plots
numberOfFakes = 1000 # recommended 1000
sensitivity = 30 # recommended 0,10,30,50,100
directory = "plots/"+str(sensitivity)

# %%
#headandshoulders
patternPrices = [0.8,0.8,0.8,0.8,1.2,0.8,1.2,1.4,1.2,1.4,1.2,0.8,1.2,0.8,0.8,0.8]
patternName = "headAndShoulders"

generatePlots(patternPrices, patternName, directory=directory, numberOfFakes=numberOfFakes, sensitivity = sensitivity)
# Out:
# Original Plot
#   0%|          | 0/1000 [00:00<?, ? plots/s]
# First fake Plots
#  33%|███▎      | 326/1000 [00:11<00:23, 28.35 plots/s]

# %%
#triangle
patternPrices = [0.7,1.3,0.8,1.2,0.9,1.1,0.95,1.05]
patternName = "triangle"

generatePlots(patternPrices, patternName, directory=directory, numberOfFakes=numberOfFakes, sensitivity = sensitivity)
# Out:
# create directory: plots/10/triangle/
# Original Plot
#   0%|          | 0/1000 [00:00<?, ? plots/s]
# First fake Plots
# 100%|██████████| 1000/1000 [00:28<00:00, 34.94 plots/s]
# True

# %%
#triple top
patternPrices = [0.7,1.3,0.7,1.3,0.7,1.3,0.7]
patternName = "tripleTop"

generatePlots(patternPrices, patternName, directory=directory, numberOfFakes=numberOfFakes, sensitivity = sensitivity)
# Out:
# create directory: plots/10/tripleTop/
# Original Plot
#   0%|          | 0/1000 [00:00<?, ? plots/s]
# First fake Plots
# 100%|██████████| 1000/1000 [00:27<00:00, 39.74 plots/s]
# True

# %%
#linear
patternPrices = [e for e in range(1,10)]
patternName = "linear"

generatePlots(patternPrices, patternName, directory=directory, numberOfFakes=numberOfFakes, sensitivity = sensitivity)
# Out:
# create directory: plots/10/linear/
# Original Plot
#   0%|          | 0/1000 [00:00<?, ? plots/s]
# First fake Plots
# 100%|██████████| 1000/1000 [00:27<00:00, 35.76 plots/s]
# True

# %%
#none
patternPrices = [1 for e in range(1,10)]
patternName = "none"

generatePlots(patternPrices, patternName, directory=directory, numberOfFakes=numberOfFakes, sensitivity = sensitivity)
# Out:
# create directory: plots/10/none/
# Original Plot
#   0%|          | 0/1000 [00:00<?, ? plots/s]
# First fake Plots
# 100%|██████████| 1000/1000 [00:30<00:00, 32.96 plots/s]
# True
